# %% [markdown]
# ## 作業:
# 在課堂中，檢定𝐻_0: 𝜇≤0， 𝐻_1: 𝜇>0，假設在𝐻_0為真下，分配為N(0,1)，𝐻_1為真下，分配為N(2,1)。
# 假設𝑋 ̅>1，拒絕𝐻_0。
# 如果拒絕域改變時，𝛼 和 𝛽 會怎樣變化。

# %% [markdown]
# ### Q1: 假設 𝑋 ̅>2，拒絕 𝐻_0，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# ### beta會變大，alpha會變小

# %% [markdown]
# ### Q2: 假設 𝑋 ̅>0.2，拒絕 𝐻_0，𝛼 會變大/變小? 𝛽 會變大/變小?

# %% [markdown]
# ### beta會變小，alpha會變大

# %% [markdown]
# ### Q3: 𝛼 和 𝛽  有關聯性?

# %% [markdown]
# ### 彼此是權衡的概念，
# alpha會變大，beta就會變小
# alpha會變小，beta就會變大
